# %% [markdown]
# ## Transform data -- categories to numbers

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')

input_path = '../data/data.csv'
output_path = '../data/transformed_data.csv'

import pandas as pd

# %% [markdown]
# First check what is actually in the data file with pandas

# %%
df = pd.read_csv(input_path)
df.head(10)
# Out:
#    txid          bookingdate issuercountrycode txvariantcode       bin  \
# 0     1  2015-11-09 14:26:51                MX      mccredit  530056.0
# 1     2  2015-11-09 14:27:38                MX      mccredit  547046.0
# 2     3  2015-11-23 16:34:16                MX      mccredit  528843.0
# 3     4  2015-11-23 16:34:51                MX      mccredit  547146.0
# 4     5  2015-11-09 14:26:08                MX   visaclassic  477291.0
# 5     6  2015-11-09 14:26:25                MX   visaclassic  493161.0
# 6     7  2015-11-09 14:26:47                MX   visaclassic  477291.0
# 7     8  2015-11-23 16:34:29                MX      mccredit  520416.0
# 8     9  2015-12-08 19:58:35                MX   visaclassic  477291.0
# 9    10  2015-11-09 14:25:50                MX      mccredit  549138.0
#
#      amount currencycode shoppercountrycode shopperinteraction simple_journal  \
# 0   64800.0          MXN                 MX          Ecommerce     Chargeback
# ...

# %% [markdown]
# Now transform the categories to number and check if results are sort of the same

# %%
from src import preprocess

df_read = preprocess.parse_data(input_path)
df_read.head(10)
# Out:
#    txid          bookingdate issuercountrycode txvariantcode       bin  \
# 0     1  2015-11-09 14:26:51                MX      mccredit  530056.0
# 1     2  2015-11-09 14:27:38                MX      mccredit  547046.0
# 2     3  2015-11-23 16:34:16                MX      mccredit  528843.0
# 3     4  2015-11-23 16:34:51                MX      mccredit  547146.0
# 4     5  2015-11-09 14:26:08                MX   visaclassic  477291.0
# 5     6  2015-11-09 14:26:25                MX   visaclassic  493161.0
# 6     7  2015-11-09 14:26:47                MX   visaclassic  477291.0
# 7     8  2015-11-23 16:34:29                MX      mccredit  520416.0
# 8     9  2015-12-08 19:58:35                MX   visaclassic  477291.0
# 9    10  2015-11-09 14:25:50                MX      mccredit  549138.0
#
#      amount currencycode shoppercountrycode shopperinteraction simple_journal  \
# 0   64800.0          MXN                 MX          Ecommerce     Chargeback
# ...

# %%
df_transformed = preprocess.category_to_number(df_read)
df_transformed.head(10)
# Out:
#    txid          bookingdate  issuercountrycode  txvariantcode       bin  \
# 0     1  2015-11-09 14:26:51                 76              2  530056.0
# 1     2  2015-11-09 14:27:38                 76              2  547046.0
# 2     3  2015-11-23 16:34:16                 76              2  528843.0
# 3     4  2015-11-23 16:34:51                 76              2  547146.0
# 4     5  2015-11-09 14:26:08                 76              6  477291.0
# 5     6  2015-11-09 14:26:25                 76              6  493161.0
# 6     7  2015-11-09 14:26:47                 76              6  477291.0
# 7     8  2015-11-23 16:34:29                 76              2  520416.0
# 8     9  2015-12-08 19:58:35                 76              6  477291.0
# 9    10  2015-11-09 14:25:50                 76              2  549138.0
#
#      amount  currencycode  shoppercountrycode  shopperinteraction  \
# 0   64800.0             2                  98                   1
# ...
