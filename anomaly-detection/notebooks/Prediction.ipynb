# %% [markdown]
# ## Predicting the next value in a series
# Visualisation of finding the optimal parameters for the model and the achieved predictions
#
# To see how these prediction are achieved, please check out the corresponding function in the provided codebase.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')

from src.data import parse_to_df
from src.easy_predict import persistence_prediction, regression_prediction
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Persistence Prediction
# The first plot shows the RMSE vs the persistence parameter p. It shows that using the value of the previous day gives the lowest RMSE. The second plot are the predictions made with p=24

# %%
persistence_prediction()
# Out:
# p=1 RMSE:14.120
# p=2 RMSE:19.956
# p=3 RMSE:24.416
# p=4 RMSE:28.168
# p=5 RMSE:31.314
# p=6 RMSE:31.334
# p=7 RMSE:30.024
# p=8 RMSE:27.808
# p=9 RMSE:24.523
# p=10 RMSE:20.175
# p=11 RMSE:16.392
# p=12 RMSE:15.048
# p=13 RMSE:16.331
# p=14 RMSE:20.327
# p=15 RMSE:24.363
# p=16 RMSE:27.666
# p=17 RMSE:29.929
# p=18 RMSE:31.178
# p=19 RMSE:30.172
# p=20 RMSE:27.893
# p=21 RMSE:24.252
# p=22 RMSE:19.794
# p=23 RMSE:14.160
# p=24 RMSE:11.699
# p=25 RMSE:15.407
# p=26 RMSE:20.326
# p=27 RMSE:24.534
# p=28 RMSE:28.286
# p=29 RMSE:30.572
# p=30 RMSE:30.671
# p=31 RMSE:29.614
# p=32 RMSE:27.150
# p=33 RMSE:23.945
# p=34 RMSE:19.812
# p=35 RMSE:16.740
# p=36 RMSE:15.694
# p=37 RMSE:17.859
# p=38 RMSE:21.392
# p=39 RMSE:24.943
# p=40 RMSE:28.059
# p=41 RMSE:30.039
# p=42 RMSE:30.745
# p=43 RMSE:29.582
# p=44 RMSE:27.090
# p=45 RMSE:23.839
# p=46 RMSE:19.265
# p=47 RMSE:14.025
# p=48 RMSE:12.920
# p=49 RMSE:16.325
# Regression RMSE=11.69908479889662

# %% [markdown]
# ### LR prediction
# Again, the first plot shows the RMSE for different window sizes. With a sliding window size of 40, the best prediction are achieved and these are shown in the second plot

# %%
regression_prediction()
# Out:
# w=1 RMSE:14.197
# w=2 RMSE:14.295
# w=3 RMSE:14.245
# w=4 RMSE:14.212
# w=5 RMSE:13.615
# w=6 RMSE:10.331
# w=7 RMSE:7.770
# w=8 RMSE:7.175
# w=9 RMSE:3.091
# w=10 RMSE:1.042
# w=11 RMSE:1.023
# w=12 RMSE:1.032
# w=13 RMSE:1.039
# w=14 RMSE:1.059
# w=15 RMSE:1.070
# w=16 RMSE:1.076
# w=17 RMSE:1.072
# w=18 RMSE:1.074
# w=19 RMSE:1.080
# w=20 RMSE:1.077
# w=21 RMSE:1.062
# w=22 RMSE:1.027
# w=23 RMSE:0.976
# w=24 RMSE:0.927
# w=25 RMSE:0.905
# w=26 RMSE:0.897
# w=27 RMSE:0.887
# w=28 RMSE:0.887
# w=29 RMSE:0.891
# w=30 RMSE:0.894
# w=31 RMSE:0.896
# w=32 RMSE:0.897
# w=33 RMSE:0.894
# w=34 RMSE:0.888
# w=35 RMSE:0.877
# w=36 RMSE:0.868
# w=37 RMSE:0.857
# w=38 RMSE:0.851
# w=39 RMSE:0.836
# w=40 RMSE:0.833
# w=41 RMSE:0.836
# w=42 RMSE:0.838
# w=43 RMSE:0.841
# w=44 RMSE:0.847
# w=45 RMSE:0.854
# w=46 RMSE:0.864
# w=47 RMSE:0.871
# w=48 RMSE:0.871
# w=49 RMSE:0.871
# Regression RMSE=0.8332557194990841
